# %% [markdown]
# # 1. Speech to text

# %% [markdown]
# ## 1.1. Install library

# %%
#!pip3 install SpeechRecognition pydub
import speech_recognition as sr

# %% [markdown]
# ## 1.2. Specify file location

# %%
filename = "/Users/justinshin/Desktop/Bootcamp/final_project/From-motion-to-emotion/Elyesa/1_speech_to_text_long.wav"

# %% [markdown]
# ## 1.3. Audio to text covertion

# %%
r = sr.Recognizer()

# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.95056194,
#                            'transcript': 'his abode which he had fixed in a '
#                                          'battery or country seat at a short '
#                                          'distance from the city just at what '
#                                          'is now called Dutch Street sooner '
#                                          'bounded with proofs of his ingenuity '
#                                          'patterned smoked sharks that '
#                                          'required a horse to work them Dutch '
#                                          'ovens that roasted meat without fire '
#                                          'carts that went before the horses '
#                                          'weather clocks that turned against '
#                                          'the wind and other one headed '
# ...

# %% [markdown]
# # 2. Sentiment analysis

# %% [markdown]
# ## 2.1. Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
plt.style.use('ggplot')

from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %% [markdown]
# ## 2.2. Read data

# %%
text
# Out:
# 'his abode which he had fixed in a battery or country seat at a short distance from the city just at what is now called Dutch Street sooner bounded with proofs of his ingenuity patterned smoked sharks that required a horse to work them Dutch ovens that roasted meat without fire carts that went before the horses weather clocks that turned against the wind and other one headed contrivances that astonished and confounded all the holders'

# %% [markdown]
# ## 2.3. Token NLTK

# %%
tokens = nltk.word_tokenize(text)
tokens
# Out:
# ['his',
#  'abode',
#  'which',
#  'he',
#  'had',
#  'fixed',
#  'in',
#  'a',
#  'battery',
#  'or',
#  'country',
#  'seat',
#  'at',
#  'a',
#  'short',
#  'distance',
#  'from',
#  'the',
#  'city',
#  'just',
#  'at',
#  'what',
#  'is',
#  'now',
#  'called',
#  'Dutch',
#  'Street',
#  'sooner',
#  'bounded',
#  'with',
#  'proofs',
#  'of',
#  'his',
#  'ingenuity',
#  'patterned',
#  'smoked',
#  'sharks',
#  'that',
#  'required',
#  'a',
#  'horse',
#  'to',
#  'work',
#  'them',
#  'Dutch',
#  'ovens',
#  'that',
#  'roasted',
#  'meat',
#  'without',
#  'fire',
#  'carts',
#  'that',
#  'went',
#  'before',
#  'the',
#  'horses',
#  'weather',
#  'clocks',
#  'that',
#  'turned',
#  'against',
#  'the',
#  'wind',
#  'and',
#  'other',
#  'one',
#  'headed',
#  'contrivances',
#  'that',
#  'astonished',
#  'and',
#  'confounded',
#  'all',
#  'the',
#  'holders']

# %%
tagged = nltk.pos_tag(tokens)
tagged
# Out:
# [('his', 'PRP$'),
#  ('abode', 'NN'),
#  ('which', 'WDT'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('fixed', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('battery', 'NN'),
#  ('or', 'CC'),
#  ('country', 'NN'),
#  ('seat', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('short', 'JJ'),
#  ('distance', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('just', 'RB'),
#  ('at', 'IN'),
#  ('what', 'WP'),
#  ('is', 'VBZ'),
#  ('now', 'RB'),
#  ('called', 'VBN'),
#  ('Dutch', 'NNP'),
#  ('Street', 'NNP'),
#  ('sooner', 'RB'),
#  ('bounded', 'VBD'),
#  ('with', 'IN'),
#  ('proofs', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('ingenuity', 'NN'),
#  ('patterned', 'VBN'),
#  ('smoked', 'VBD'),
#  ('sharks', 'NNS'),
#  ('that', 'WDT'),
#  ('required', 'VBD'),
#  ('a', 'DT'),
#  ('horse', 'NN'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('them', 'PRP'),
#  ('Dutch', 'VB'),
#  ('ovens', 'NNS'),
#  ('that', 'WDT'),
#  ('roasted', 'VBD'),
#  ('meat', 'NN'),
#  ('without', 'IN'),
# ...

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   his/PRP$
#   abode/NN
#   which/WDT
#   he/PRP
#   had/VBD
#   fixed/VBN
#   in/IN
#   a/DT
#   battery/NN
#   or/CC
#   country/NN
#   seat/NN
#   at/IN
#   a/DT
#   short/JJ
#   distance/NN
#   from/IN
#   the/DT
#   city/NN
#   just/RB
#   at/IN
#   what/WP
#   is/VBZ
#   now/RB
#   called/VBN
#   (PERSON Dutch/NNP Street/NNP)
#   sooner/RB
#   bounded/VBD
#   with/IN
#   proofs/NN
#   of/IN
#   his/PRP$
#   ingenuity/NN
#   patterned/VBN
#   smoked/VBD
#   sharks/NNS
#   that/WDT
#   required/VBD
#   a/DT
#   horse/NN
#   to/TO
#   work/VB
#   them/PRP
#   Dutch/VB
#   ovens/NNS
#   that/WDT
#   roasted/VBD
#   meat/NN
#   without/IN
#   fire/NN
#   carts/NNS
#   that/WDT
#   went/VBD
#   before/IN
#   the/DT
#   horses/NNS
#   weather/VBP
#   clocks/NNS
#   that/WDT
#   turned/VBD
#   against/IN
#   the/DT
#   wind/NN
#   and/CC
#   other/JJ
#   one/CD
#   headed/VBN
#   contrivances/NNS
#   that/IN
#   astonished/VBD
#   and/CC
#   confounded/VBD
#   all/PDT
#   the/DT
# ...

# %% [markdown]
# ## 2.4. NLTK SentimentIntensityAnalyzer()

# %%
sentiment = sia.polarity_scores(text)

# %%
sentiment
# Out:
# {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'compound': 0.5627}

# %%
max(sentiment, key=sentiment.get)
# Out:
# 'neu'

# %% [markdown]
# # 3. Emotion detecting from voice

# %% [markdown]
# ## 3.1. Visualize Audio

# %% [markdown]
# resource = https://learnpython.com/blog/plot-waveform-in-python/

# %%
import wave
wav_obj = wave.open(filename, 'rb')

# %%
# A sound wave is a continuous quantity that needs to be sampled at some time interval to digitize it. 
# The sampling rate quantifies how many samples of the sound are taken every second.
sample_freq = wav_obj.getframerate()
sample_freq
# Out:
# 16000

# %%
# The sample frequency quantifies the number of samples per second. In this case
n_samples = wav_obj.getnframes()
n_samples
# Out:
# 562480

# %%
# how long the audio file is in seconds
t_audio = n_samples/sample_freq
t_audio
# Out:
# 35.155

# %%
# The audio file is recorded in stereo, that is, in two independent audio channels. 
# This creates the impression of the sound coming from two different directions. 
# We can check the number of channels as follows:
n_channels = wav_obj.getnchannels()
n_channels
# Out:
# 1

# %%
#The next step is to get the values of the signal, that is, the amplitude of the wave at that point in time. 
#To do this, we can use the readframes() method, which takes one argument, n, defining the number of frames to read:
signal_wave = wav_obj.readframes(n_samples)

# %%
#This method returns a bytes object. Check for yourself by using the type() built-in function on the signal_wave object. 
#To get signal values from this, we have to turn to numpy:
import numpy as np
signal_array = np.frombuffer(signal_wave, dtype=np.int16)

# %%
signal_array
# Out:
# array([ 16,   4,   9, ...,   6, -26, -42], dtype=int16)

# %% [markdown]
# This returns all data from both channels as a 1-dimensional array. If you check the shape of signal_array, you notice it has 10,768,652 elements, which is exactly n_samples * n_channels. To split the data into individual channels, we can use a clever little array slice trick:

# %%
# if it two chanel use this code 

##This returns all data from both channels as a 1-dimensional array. 
##If you check the shape of signal_array, you notice it has 10,768,652 elements, 
##which is exactly n_samples * n_channels. To split the data into individual channels, 
##we can use a clever little array slice trick:
#l_channel = signal_array[0::2]
#r_channel = signal_array[1::2]

# %% [markdown]
# Now, our left and right channels are separated, both containing 5,384,326 integers representing the amplitude of the signal.
#
# Next, we show some examples of how to plot the signal values. We have our data stored in arrays here, but for many data science applications, pandas is very useful. Check out THIS ARTICLE about visualizing data stored in a DataFrame.

# %%
times = np.linspace(0, n_samples/sample_freq, num=n_samples)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(times, signal_array)
#plt.plot(times, l_channel)
#use above code if its two chanel
plt.title('Single Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

# %%
plt.figure(figsize=(15, 5))
#plt.specgram(l_channel, Fs=sample_freq, vmin=-20, vmax=50)
plt.specgram(signal_array, Fs=sample_freq, vmin=-20, vmax=50)
plt.title('Single Channel')
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.colorbar()
plt.show()
# Out:
# /var/folders/45/j2jnqkdd5t78wm5cnmbf7l740000gn/T/ipykernel_22296/1458848722.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %% [markdown]
# The hertz is the unit of frequency in the International System of Units, equivalent to one event per second.
# 1 MHz = 1000000 Hz = 1000 kHz = 0.001 GHz.
# 1 Hz = 100 frenquency / second
